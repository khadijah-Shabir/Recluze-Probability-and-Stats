# %%
import pandas as pd

# %%
url="data/NHANES.csv"
df=pd.read_csv(url)

# %%
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
df.shape
# Out:
# (5735, 28)

# %%
df.columns
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
series_1=df['BMXBMI']
series_1
# Out:
# 0       27.8
# 1       30.8
# 2       28.8
# 3       42.4
# 4       20.3
#         ...
# 5730    21.5
# 5731    33.8
# 5732    31.0
# 5733    26.0
# 5734    21.4
# Name: BMXBMI, Length: 5735, dtype: float64

# %%
series_1=series_1.dropna()
series_1
# Out:
# 0       27.8
# 1       30.8
# 2       28.8
# 3       42.4
# 4       20.3
#         ...
# 5730    21.5
# 5731    33.8
# 5732    31.0
# 5733    26.0
# 5734    21.4
# Name: BMXBMI, Length: 5662, dtype: float64

# %%
series_1.shape
# Out:
# (5662,)

# %% [markdown]
# **Visualization**

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
num=[2,4,6,8,10]

# %%
plt.plot(num)

# %%
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(num)
plt.xlabel("x values (sec)")
plt.ylabel("y values (meters)")
plt.title("first example plot")
plt.grid()
plt.show()

# %%
df['BMXWT'].size
# Out:
# 5735

# %%
plt.figure(figsize=(10,5))

x=range(df['BMXWT'].size)
y=df['BMXWT']

plt.scatter(x,y, marker='x', s=0.3)
plt.xlabel("ID of individual")
plt.ylabel("weight in kg")
plt.title("weights of individuals")

plt.show()

# %%
sum(y)
# Out:
# nan

# %%
y=y.dropna()

# %%
sum(y)
# Out:
# 460887.6

# %%
avg= sum(y) / len(y)

# %%
avg
# Out:
# 81.34267560889516
