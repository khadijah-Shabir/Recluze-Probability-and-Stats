# %%
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %%
import pandas as pd
url = "data/nhanes.csv"
df = pd.read_csv(url)
df.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# 1     40.0     33.2     107.9     NaN
# 2     37.0     31.0     116.5     2.0
# 3     37.7     38.3     110.1     2.0
# 4     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %% [markdown]
# **Studying Discrete Values**

# %%
gender = df['RIAGENDR']
gender.value_counts()
# Out:
# RIAGENDR
# 2    2976
# 1    2759
# Name: count, dtype: int64

# %%
gender.value_counts().plot(kind='bar')
plt.show()

# %%
gender.value_counts().plot(kind='bar')
plt.xticks([0,1],['male', 'female'])
plt.xlabel("gender")
plt.ylabel("frequency")
plt.title("gender frequency overview")
plt.show()

# %% [markdown]
# **Most common Value**

# %%
sizes=np.array([22, 23, 29, 32, 39, 42, 42, 42, 42, 42, 42, 42, 42, 43, 44, 46, 51, 51, 55, 55, 57, 58, 78, 83, 97, 97])

# %%
sizes.mean()
# Out:
# 49.84615384615385

# %%
from collections import Counter
cnt=Counter()

for i in sizes:
    cnt[i]+=1

cnt.most_common()
# Out:
# [(42, 8),
#  (51, 2),
#  (55, 2),
#  (97, 2),
#  (22, 1),
#  (23, 1),
#  (29, 1),
#  (32, 1),
#  (39, 1),
#  (43, 1),
#  (44, 1),
#  (46, 1),
#  (57, 1),
#  (58, 1),
#  (78, 1),
#  (83, 1)]

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\khadijah\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\khadijah\anaconda3\lib\site-packages (from scipy) (1.26.4)

# %%
from scipy import stats
stats.mode(sizes)
# Out:
# ModeResult(mode=42, count=8)

# %%
gender.mode()   # not too useful since we could have got that from the bar chart anyway
# Out:
# 0    2
# Name: RIAGENDR, dtype: int64

# %%
stats.mode(gender)
# Out:
# ModeResult(mode=2, count=2976)

# %% [markdown]
# **More than One "Classes "**

# %%
df['HIQ210'].unique()
# Out:
# array([ 2., nan,  1.,  9.])

# %%
df['HIQ210'].value_counts().plot(kind='bar')
plt.show()

# %%
df['HIQ210'].value_counts().plot(kind='pie')  # highly NOT recommended! 
plt.show()

# %%
wt = df['BMXWT']
wt.unique()
# Out:
# array([ 94.8,  90.4,  83.4, 109.8,  55.2,  64.4,  76.6,  64.5,  72.4,
#        108.3,  86.2,  76.2,  71.2, 117.8,  97.4,  80.5, 100.8,  61.8,
#        107.9,  59. ,  72.8,  67.7,  77.7,  56.6,  69. ,  87.8,  73.7,
#         75.6, 102.1,  77.4,  84. , 102.9,  85.6,  78.6,  66.6,  58.5,
#         68.4,  79.1,  72.9,  63.7,  89.2,  59.3,  86.1,  72.3,  81.7,
#         79.8,  60.4,  66.8,  93. ,  71.3,  65.8, 105.9,  87.7,  68.6,
#         77.5,  78.3,  68.9, 133.3,  80.3,  85.1,  76.1, 110.2,  89.1,
#         70.4, 146.1,  60.3,  95.8,  39.7,  88. ,  61.3,  82.4,  53.7,
#         67.2,  91.2,  91.6,  61.5,  49.7,  63.2,  46.7,  62.2,  48.7,
#         84.1,  51.4,  50.5, 109.5,  58.9,  56.2,  86. ,  75.3,  73. ,
#         90.7,  71.5,  70.5,  95.7,  73.2,  91.1,  72.5,  99.3,  90. ,
#         64.7,  85.7,  93.8,  57.9,  77.8,  55.4,  78.7,  65.7,  90.8,
#         55.7,  56.4,  82.5,  92.3, 116.7,  73.5,  78.9,  71.4,  56.5,
#         67.9,  78.4,  93.1,  58.6, 126.3, 147. ,  67. , 129.3, 120.1,
#         60.9, 109.2,  77.6,  74.6,  48.2,  57.5,  98.1,  97.1, 105.1,
#         72.2, 121.9,  96.8, 143.6,  91.3,  48.6,  73.4,  78. , 137.7,
#         85. ,  60.1, 119.6,  69.2,  71.6, 110.1,  82.2,  81.5, 158.2,
#         49.4,  96.2, 136.2,  51.1,  63.8,  89.7,  44.6, 100.2,  78.8,
#         82.8,  60.8,  63.9,  50.7,  95.9,  49.5,  68. ,  80.4,  67.4,
#         80.6,  83.8,  86.9,  80.2,  59.8,   nan,  76.4,  51.8,  84.9,
#         60.7,  60. ,  78.2,  60.6,  51.3,  57.3,  69.8,  67.3,  89. ,
#         68.5,  53.3,  87.5,  74.3, 108.2,  69.1,  68.7,  53.2,  73.8,
#         63.4,  83.2, 107.6, 131.6,  62.5,  50.8,  45.9,  64.9, 102.3,
#         67.8,  81.9,  92.9,  76. ,  79.3,  45.4, 140.9,  69.4,  81. ,
#         77.1, 150. ,  52.5,  69.7,  90.2,  54.1,  59.2,  67.5,  91.5,
#        102.5, 110.5,  84.4,  62.9, 118.1,  74. ,  93.3,  96.7,  66.3,
#        165.6,  82.1, 115. ,  81.8,  66. ,  88.6,  61.9,  76.7, 142.1,
#        114.6, 117.6, 115.6,  34.8, 116. , 141.1, 192.3, 134.5,  98.2,
#        118.6, 122.8,  47.6, 131.4, 156.4, 139.6, 110.7, 129.9, 122.6,
#        100. ,  53.4, 125.1, 112. , 152.3, 125.3,  89.6, 118.7, 119. ,
#        132.2, 133.8,  43.9, 130.2, 127.1, 111.8,  54.7, 117.2,  46.5,
#         49.1, 113.3, 123.2,  97. , 160.4, 114.8,  50.9, 127.7, 161.2,
#        154.2,  48.1, 130. , 111.9, 130.7,  46.6,  49.9, 108.1, 108.9,
#        119.3,  40.7, 113.4, 124.8, 168.6, 142.5, 133.6,  88.8, 120.3,
#        111. , 173.4, 145.8, 114.3,  92.8,  91.4, 108.8, 107.5,  93.5,
#        118.3,  47.9, 134.2, 125.6, 140.4, 141.9, 181.5,  32.4, 104.1,
#        155.9, 122.1,  41.5, 124.7, 117.7, 101.7, 113.1, 146.6,  45.8,
#         92. , 126.5, 143.9, 117.9, 112.4, 181. , 124.1, 113.9, 115.4,
#        128.6, 123.3,  41.3, 178.9, 129.5, 129.1, 127.6, 117.4, 169.4,
#         98.3, 121.8, 110.8,  57.8, 155.6,  42.6, 161.9,  47.5,  44.4,
#        145.1, 131.7, 134.8, 178.4,  48.8, 114.1,  51.7, 175.3, 135.4,
#        140.1, 123.6, 120.4, 137. ,  51. , 131.5,  42.2, 122.5, 143.7,
#        103.4, 112.5, 126.1, 121.4,  40.2, 103.1, 125.5, 124.5, 116.8,
#        133. ,  41.2, 113.6, 132.8, 135.3, 121.1, 129.7, 134.7, 121.5,
#        127.9, 154.6,  44.8, 124.3, 159.9, 130.1, 126. ,  50.1, 110.3,
#         47.2,  45.5,  44.9,  45.7, 145.5, 117. , 138. , 119.8, 116.1,
#        108. , 138.7, 120.5,  36. , 132. ,  52.7,  43. ,  49.8, 144.9,
#        133.5, 112.9, 123.5, 131.3, 143.2, 120. , 147.8, 139.4,  43.4,
#        152. , 175.9, 127.3,  41.6, 159.2, 145. , 112.3, 107.7, 128. ,
#        173. ,  39.8, 133.9,  42.7, 178.3, 146.7, 115.8,  39.2])

# %%
wt.hist(bins=20)
plt.show()

# %%
plt.hist(wt,bins=20)
plt.ylabel('Frequency')
plt.xlabel('Weights');
plt.title("Histogram of Weights in NHANES Dataset")
plt.show()

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\khadijah\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\khadijah\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\khadijah\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\khadijah\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\khadijah\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\khadijah\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khadijah\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\khadijah\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\khadijah\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\khadijah\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\khadijah\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\khadijah\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khadijah\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khadijah\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\khadijah\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")

# %%
sns.distplot(wt,bins=20, kde=False)
plt.ylabel('Frequency')
plt.xlabel('Weights');
plt.title("Histogram of Weights in NHANES Dataset")
sns.despine(offset=10, trim=True)
plt.show()
# Out:
# C:\Users\Khadijah\AppData\Local\Temp\ipykernel_19416\1450716182.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wt,bins=20, kde=False)

# %% [markdown]
# **Studying Central Tendency**

# %%
plt.figure(figsize=(20,5))
x=range(df['BMXWT'].size)
y=df['BMXWT']
plt.scatter(x,y,marker='x', s=0.5)
plt.title("Weights of Individuals")
plt.xlabel("ID of Individual")
plt.ylabel("Weight (kg)")


p1=(0,75)
p2=(6000,75)
x1,y1=zip(p1,p2)
plt.plot(x1,y1, color='red', linewidth=0.75)
plt.show()

# %%
plt.figure(figsize=(20,5))
x=range(df['BMXWT'].size)
y=df['BMXWT']
plt.scatter(x,y, marker='x', s=0.5)

# plot the estimate line 
x_c, y_c = ([0, 6000], [75, 75])
plt.plot(x_c, y_c, color='red', linewidth=0.75)

# plot the estimate line 
x_c, y_c = ([0, 6000], [wt.mean(), wt.mean()])
plt.plot(x_c, y_c, color='green', linewidth=2)
plt.show()

# %% [markdown]
# **Problem with Arithmetic Mean**

# %%
import numpy as np

# %%
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 97])

# %%
np.mean(nums)
# Out:
# 30.625

# %%
np.median(nums)
# Out:
# 26.0

# %% [markdown]
# **Visualizing Weights Data**

# %%
wt.mean()
# Out:
# 81.34267560889516

# %%
wt.median()
# Out:
# 78.2

# %%
wt.min()
# Out:
# 32.4

# %%
wt.max()
# Out:
# 198.9

# %%
plt.figure(figsize=(20, 5)) 

x =  range(df['BMXWT'].size)
y =  df['BMXWT']

plt.scatter(x, y, marker='x', s=0.5)

plt.title("Weights of Individuals")
plt.xlabel("ID of Individual")
plt.ylabel("Weight (kg)")

x_c, y_c= ([0,6000],[wt.mean(),wt.mean()])
plt.plot(x_c,y_c, color='red', linewidth=0.75)

x_c, y_c= ([0,6000],[wt.median(),wt.median()])
plt.plot(x_c,y_c, color='green', linewidth=2)

plt.show()

# %% [markdown]
# **Quartiles and Boxplots**

# %%
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 97])

# %%
np.median(nums)
# Out:
# 26.0

# %%
import statistics

# %%
statistics.quantiles(nums, n=4)
# Out:
# [17.25, 26.0, 42.0]

# %%
statistics.quantiles(wt,n=4)
# Out:
# [43.7, 52.5, 50.1]

# %%
ax=sns.boxplot(x=wt)
plt.show()

# %%
male=df.loc[df['RIAGENDR']==2, 'BMXWT']
male.mean()
# Out:
# 76.51676280963693

# %%
female=df.loc[df['RIAGENDR']==1, 'BMXWT']
female.mean()
# Out:
# 86.57326222876058

# %%
plt.figure(figsize=(20,10))
sns.set_style("whitegrid")
sns.boxplot(x="RIAGENDR", y='BMXWT', data=df, palette='Set3')
plt.show()
# Out:
# C:\Users\Khadijah\AppData\Local\Temp\ipykernel_19416\3117203500.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="RIAGENDR", y='BMXWT', data=df, palette='Set3')
